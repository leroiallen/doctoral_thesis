# %%
from math import pi
# %matplotlib inline
import matplotlib.pyplot as plt

cluster_1 = [2.56,
2.44,
1.83,
1.68,
1.48,
2.50,
1.72,
2.02,
2.07,
2.14,
2.13,
2.14,
1.95,
1.73,
2.02,
1.64,
1.152,
1.57,
1.47,
1.27,
1.59,
1.72,
2.56,
1.22,
1.48,
4.13,
2.08,
1.75,
1.50,
1.94
]

cluster_2 = [1.95,
2.43,
1.43,
1.31,
1.27,
1.86,
1.69,
4.41,
4.49,
4.27,
4.53,
4.08,
4.21,
3.27,
1.88,
1.29,
1.14,
1.35,
1.37,
1.21,
2.67,
1.90,
2.35,
1.88,
2.85,
5.06,
4.39,
1.90,
2.15,
4.04
]

cluster_3 = [6.11,
4.82,
5.41,
5.06,
3.76,
6.24,
5.15,
4.58,
4.71,
5.43,
5.29,
4.67,
5.53,
3.11,
3.85,
3.71,
1.65,
3.43,
3.58,
2.94,
3.54,
5.00,
6.63,
5.04,
5.35,
6.90,
5.84,
5.59,
5.54,
5.77
]

cluster_4 = [5.05,
4.13,
3.69,
3.47,
3.31,
4.89,
3.84,
2.96,
3.015,
3.06,
3.16,
2.92,
2.98,
2.84,
2.39,
2.95,
1.86,
3.06,
2.52,
1.932,
2.51,
3.61,
4.75,
1.69,
2.90,
4.74,
3.41,
3.40,
3.13,
3.44
]

cluster_1 += cluster_1[:1]
cluster_2 += cluster_2[:1]
cluster_3 += cluster_3[:1]
cluster_4 += cluster_4[:1]

N=30

angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]

golden = '#fac205'
blue = '#a2cffe'
red = 'salmon'
green = '#02ab2e'

plt.figure(figsize=(10,8))
ax1=plt.subplot(111, polar=True)
ax1.set_rlabel_position(0)
line_1 = ax1.plot(angles, cluster_1, linewidth=5, color=red)
line_2 = ax1.plot(angles, cluster_2, linewidth=5, color=blue)
line_3 = ax1.plot(angles, cluster_3, linewidth=5, color=green)
line_4 = ax1.plot(angles, cluster_4, linewidth=5, color=golden)
plt.xticks(angles[:-1], ['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 
                         'N1', 'N2', 'N3', 'N4', 'N5', 'N6', 'N7',
                        'G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10', 'G11', 'G12', 'G13', 'G14', 'G15', 'G16'], 
           color='black', size=20,  verticalalignment= 'center')
plt.legend((line_1[0],line_2[0],line_3[0], line_4[0]),
           ('Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4'), loc=(0.95,0.9), fontsize=14)
plt.yticks([1,2,3,4,5,6], ['','','','','',''], color="grey", size=13)
plt.ylim(0,7)
ax1.tick_params('x', pad=15)

plt.savefig('panss_png_kmeans_radar_chart_p_n_g.png',dpi=300)

# %%
from math import pi
# %matplotlib inline
import matplotlib.pyplot as plt

cluster_1_p_n = [2.56,
2.44,
1.83,
1.68,
1.48,
2.50,
1.72,
2.02,
2.07,
2.14,
2.13,
2.14,
1.95,
1.73
]

cluster_2_p_n = [1.95,
2.43,
1.43,
1.31,
1.27,
1.86,
1.69,
4.41,
4.49,
4.27,
4.53,
4.08,
4.21,
3.27,
]

cluster_3_p_n = [6.11,
4.82,
5.41,
5.06,
3.76,
6.24,
5.15,
4.58,
4.71,
5.43,
5.29,
4.67,
5.53,
3.11
]

cluster_4_p_n = [5.05,
4.13,
3.69,
3.47,
3.31,
4.89,
3.84,
2.96,
3.015,
3.06,
3.16,
2.92,
2.98,
2.84
]

cluster_1_p_n += cluster_1_p_n[:1]
cluster_2_p_n += cluster_2_p_n[:1]
cluster_3_p_n += cluster_3_p_n[:1]
cluster_4_p_n += cluster_4_p_n[:1]

N=14

angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]

golden = '#fac205'
blue = '#a2cffe'
red = 'salmon'
green = '#02ab2e'

plt.figure(figsize=(10,8))
ax1=plt.subplot(111, polar=True)
ax1.set_rlabel_position(0)
line_1 = ax1.plot(angles, cluster_1_p_n, linewidth=5, color=red)
line_2 = ax1.plot(angles, cluster_2_p_n, linewidth=5, color=blue)
line_3 = ax1.plot(angles, cluster_3_p_n, linewidth=5, color=green)
line_4 = ax1.plot(angles, cluster_4_p_n, linewidth=5, color=golden)
plt.xticks(angles[:-1], ['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 
                         'N1', 'N2', 'N3', 'N4', 'N5', 'N6', 'N7'], 
           color='black', size=20)
plt.legend((line_1[0],line_2[0],line_3[0], line_4[0]),
           ('Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4'), loc=(0.95,0.9), fontsize=14)
plt.yticks([1,2,3,4,5,6], ['','','','','',''], color="grey", size=13)
plt.ylim(0,7)
ax1.tick_params('x', pad=10)

plt.savefig('panss_png_kmeans_radar_chart_p_n.png',dpi=300)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.bar([1,3,5,7],[44,28,10,18], width=1.5)
plt.xticks([1,3,5,7],['Cluster 1','Cluster 2','Cluster 3', 'Cluster 4'])
plt.ylabel('Percentage (%)')
plt.savefig('panss_png_kmeans_percentage.png',dpi=300)

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import Imputer
from sklearn import cluster, metrics

#读取csv数据
def read_data(path):
	data = pd.read_csv(path)
	#数据全部转换为float64
	data = data.astype('float64')
	return data

#定位缺失值
def find_null(data):
    for columname in data.columns:
        if data[columname].count() != len(data):
            loc = data[columname][data[columname].isnull().values==True].index.tolist()
            print(columname, loc)
    return

#以中位数替换缺失值
def fill_null(data, fill_null_with='median'):
	imp = Imputer(missing_values='NaN', strategy = fill_null_with, axis=0)
	imp.fit(data)
	Imputer(axis=0, copy=True, missing_values='NaN', strategy=fill_null_with, verbose=0)
	data_imputed = imp.transform(data)
	return data_imputed

panss_p_n_g = read_data('panss_p_n_g.csv')

find_null(panss_p_n_g)

panss_p_n_g_imputed = fill_null(panss_p_n_g, fill_null_with='median')

#标准化数据进行后续操作
panss_p_n_g_imputed_mean = np.mean(panss_p_n_g_imputed, axis=0)
panss_p_n_g_imputed_std = np.std(panss_p_n_g_imputed, axis=0)
panss_p_n_g_imputed_standardized = preprocessing.scale(panss_p_n_g_imputed)

#进行KMean

kmeans_fit = cluster.KMeans(n_clusters = 4).fit(panss_p_n_g_imputed_standardized)
cluster_labels = kmeans_fit.labels_
cluster_centers = kmeans_fit.cluster_centers_

cluster_centers_not_imputed=cluster_centers * panss_p_n_g_imputed_std+panss_p_n_g_imputed_mean

print cluster_centers_not_imputed

from collections import Counter
Counter(cluster_labels)
# Out:
# ('panss_n1', [108])
# ('panss_n3', [584])
# ('panss_g8', [114])
# [[2.56097561 2.43902439 1.82621951 1.67682927 1.47560976 2.49695122
#   1.72256098 2.01829268 2.06707317 2.1402439  2.12804878 2.13719512
#   1.95426829 1.73170732 2.02134146 1.63719512 1.15243902 1.57012195
#   1.47256098 1.27439024 1.58536585 1.72256098 2.56402439 1.2195122
#   1.47560976 4.13109756 2.07926829 1.74695122 1.5        1.94207317]
#  [5.06666667 4.11111111 3.71111111 3.45925926 3.2962963  4.9037037
#   3.84444444 2.96296296 3.01481481 3.05185185 3.16296296 2.91111111
#   2.97777778 2.83703704 2.41481481 2.95555556 1.85925926 3.05185185
#   2.52592593 1.93333333 2.51111111 3.61481481 4.77037037 1.7037037
#   2.91111111 4.75555556 3.42962963 3.39259259 3.15555556 3.45185185]
#  [6.1025641  4.85897436 5.38461538 5.1025641  3.78205128 6.23076923
#   5.16666667 4.6025641  4.73076923 5.47435897 5.32051282 4.70512821
#   5.56410256 3.12820513 3.82051282 3.70512821 1.64102564 3.44871795
# ...

# %%
pd.DataFrame(cluster_labels).to_csv('panss_png_kmeans_label.csv')

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt

two_labels = pd.read_excel('comparison_between_pn_kmeans_and_png_kmeans.xlsx')

import matplotlib.patches as patches

fig = plt.figure(figsize=(40,5))
ax = fig.add_subplot(111)

golden = '#fac205'
blue = '#a2cffe'
red = 'salmon'
green = '#02ab2e'

colors = [red, blue, green, golden]

for i in range(0,two_labels.shape[0]):
    ax.add_patch(patches.Rectangle((i, 0), 1, 2, fill=True, edgecolor=None, facecolor=colors[two_labels.iloc[i,1]]))
    ax.add_patch(patches.Rectangle((i, 2.5), 1, 2, fill=True, edgecolor=None, facecolor=colors[two_labels.iloc[i,2]]))

plt.xlim(-1,two_labels.shape[0]+1)
plt.ylim(-0.5,6)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
plt.yticks([])
plt.xticks([0,50,100,150,200,250,300,350,400,450,500,550,600,650,700,two_labels.shape[0]-1],
           [two_labels.iloc[0,0], two_labels.iloc[50,0], two_labels.iloc[100,0], two_labels.iloc[150,0], two_labels.iloc[200,0], two_labels.iloc[250,0], 
            two_labels.iloc[300,0], two_labels.iloc[350,0], two_labels.iloc[400,0], two_labels.iloc[450,0], two_labels.iloc[500,0], two_labels.iloc[550,0], 
            two_labels.iloc[600,0], two_labels.iloc[650,0], two_labels.iloc[700,0], two_labels.iloc[two_labels.shape[0]-1,0]], fontsize=40)

plt.savefig('comparison_between_pn_kmeans_and_png_kmeans.png', dpi=300)
