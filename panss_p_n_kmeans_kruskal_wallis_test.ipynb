# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

p1_mean = [2.48,
2.09,
5.85,
5.46
]
p1_std = [1.268,
1.278,
1.588,
1.162
]

golden = '#fac205'
blue = '#a2cffe'
red = 'salmon'
green = '#02ab2e'

xticks = ['Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4']

ax = plt.subplot(111)
ax.errorbar(range(0,4),p1_mean,yerr=p1_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_p1.png',dpi=300)

# %%
p2_mean = [2.34,
2.53,
5.06,
4.12
]
p2_std = [1.381,
1.381,
1.673,
1.320
]

golden = '#fac205'
blue = '#a2cffe'
red = 'salmon'
green = '#02ab2e'

xticks = ['Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4']

ax = plt.subplot(111)
ax.errorbar(range(0,4),p2_mean,yerr=p2_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_p2.png',dpi=300)

# %%
p3_mean = [1.75,
1.57,
5.06,
4.04
]
p3_std = [1.020,
0.915,
1.933,
1.734
]

golden = '#fac205'
blue = '#a2cffe'
red = 'salmon'
green = '#02ab2e'

xticks = ['Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4']

ax = plt.subplot(111)
ax.errorbar(range(0,4),p3_mean,yerr=p3_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_p3.png',dpi=300)

# %%
p4_mean = [1.61,
1.38,
4.71,
3.92
]
p4_std = [0.712,
0.619,
2.003,
1.531
]

golden = '#fac205'
blue = '#a2cffe'
red = 'salmon'
green = '#02ab2e'

xticks = ['Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4']

ax = plt.subplot(111)
ax.errorbar(range(0,4),p4_mean,yerr=p4_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_p4.png',dpi=300)

# %%
p5_mean = [1.42,
1.34,
3.62,
3.60
]
p5_std = [0.767,
0.712,
1.883,
1.706
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),p5_mean,yerr=p5_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_p5.png',dpi=300)

# %%
p6_mean = [2.44,
2.01,
6.00,
5.20
]
p6_std = [1.178,
1.193,
1.286,
1.269
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),p6_mean,yerr=p6_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_p6.png',dpi=300)

# %%
p7_mean = [1.70,
1.81,
4.96,
3.96
]
p7_std = [0.753,
0.975,
1.527,
1.562
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),p7_mean,yerr=p7_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_p7.png',dpi=300)

# %%
n1_mean = [2.03,
4.42,
4.87,
2.34
]
n1_std = [0.827,
0.936,
1.312,
1.077
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),n1_mean,yerr=n1_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_n1.png',dpi=300)

# %%
n2_mean = [2.08,
4.45,
5.00,
2.44
]
n2_std = [0.806,
0.863,
1.388,
1.024
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),n2_mean,yerr=n2_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_n2.png',dpi=300)

# %%
n3_mean = [2.15,
4.26,
5.65,
2.53
]
n3_std = [0.820,
0.956,
1.058,
1.073
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),n3_mean,yerr=n3_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_n3.png',dpi=300)

# %%
n4_mean = [2.15,
4.52,
5.56,
2.53
]
n4_std = [0.824,
0.931,
1.187,
1.065
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),n4_mean,yerr=n4_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_n4.png',dpi=300)

# %%
n5_mean = [2.14,
4.08,
4.94,
2.40
]
n5_std = [0.959,
1.130,
1.299,
1.201
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),n5_mean,yerr=n5_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_n5.png',dpi=300)

# %%
n6_mean = [1.99,
4.22,
5.77,
2.31
]
n6_std = [0.806,
0.984,
1.136,
1.103
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),n6_mean,yerr=n6_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_n6.png',dpi=300)

# %%
n7_mean = [1.76,
3.33,
3.68,
2.06
]
n7_std = [0.805,
1.444,
1.256,
1.090
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),n7_mean,yerr=n7_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_n7.png',dpi=300)

# %%
g1_mean = [2.06,
1.99,
3.34,
2.47
]
g1_std = [1.011,
1.111,
1.737,
1.628
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),g1_mean,yerr=g1_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_g1.png',dpi=300)

# %%
g2_mean = [1.66,
1.51,
3.40,
2.85
]
g2_std = [0.812,
0.953,
1.624,
1.464
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),g2_mean,yerr=g2_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_g2.png',dpi=300)

# %%
g3_mean = [1.17,
1.23,
1.77,
1.64
]
g3_std = [0.456,
0.626,
1.210,
0.837
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),g3_mean,yerr=g3_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_g3.png',dpi=300)

# %%
g4_mean = [1.56,
1.54,
3.23,
3.00
]
g4_std = [0.662,
0.948,
1.709,
1.455
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),g4_mean,yerr=g4_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_g4.png',dpi=300)

# %%
g5_mean = [1.49,
1.55,
3.38,
2.36
]
g5_std = [0.729,
0.970,
1.607,
1.454
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),g5_mean,yerr=g5_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_g5.png',dpi=300)

# %%
g6_mean = [1.29,
1.36,
2.78,
1.74
]
g6_std = [0.626,
0.902,
1.414,
0.962
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),g6_mean,yerr=g6_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_g6.png',dpi=300)

# %%
g7_mean = [1.64,
2.80,
3.61,
1.92
]
g7_std = [0.861,
1.649,
1.683,
1.152
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),g7_mean,yerr=g7_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_g7.png',dpi=300)

# %%
g8_mean = [1.68,
2.03,
4.67,
3.79
]
g8_std = [0.762,
1.165,
1.879,
1.624
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),g8_mean,yerr=g8_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_g8.png',dpi=300)

# %%
g9_mean = [2.50,
2.55,
6.24,
4.97
]
g9_std = [1.121,
1.337,
1.150,
1.576
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),g9_mean,yerr=g9_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_g9.png',dpi=300)

# %%
g10_mean = [1.22,
1.91,
4.34,
1.95
]
g10_std = [0.458,
1.211,
1.772,
1.460
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),g10_mean,yerr=g10_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_g10.png',dpi=300)

# %%
g11_mean = [1.49,
2.80,
4.77,
3.12
]
g11_std = [0.684,
1.410,
1.687,
1.626
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),g11_mean,yerr=g11_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_g11.png',dpi=300)

# %%
g12_mean = [4.09,
5.00,
6.46,
5.07
]
g12_std = [1.751,
1.180,
1.102,
1.644
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),g12_mean,yerr=g12_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_g12.png',dpi=300)

# %%
g13_mean = [2.10,
4.23,
5.39,
3.59
]
g13_std = [0.983,
1.275,
1.489,
1.447
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),g13_mean,yerr=g13_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_g13.png',dpi=300)

# %%
g14_mean = [1.75,
2.02,
5.20,
3.50
]
g14_std = [0.884,
1.198,
1.551,
1.728
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),g14_mean,yerr=g14_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_g14.png',dpi=300)

# %%
g15_mean = [1.53,
2.29,
5.18,
3.00
]
g15_std = [0.715,
1.347,
1.467,
1.915
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),g15_mean,yerr=g15_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks([1,2,3,4,5,6,7],fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_g15.png',dpi=300)

# %%
psum_mean = [13.75,
12.73,
35.27,
30.30
]
psum_std = [4.004,
4.524,
7.965,
6.181
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),psum_mean,yerr=psum_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks(range(7,50,7),fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,56)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_psum.png',dpi=300)

# %%
nsum_mean = [14.30,
29.28,
35.46,
16.61
]
nsum_std = [4.517,
5.194,
5.895,
5.168
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),nsum_mean,yerr=nsum_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks(range(7,50,7),fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,56)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_nsum.png',dpi=300)

# %%
gsum_mean = [29.23,
38.76,
69.50,
48.12
]
gsum_std = [6.376,
9.058,
13.210,
13.034
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),gsum_mean,yerr=gsum_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks(range(16,7*16+1,16),fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8*16)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_gsum.png',dpi=300)

# %%
sum_mean = [57.27,
80.77,
140.23,
95.02
]
sum_std = [11.420,
14.401,
19.205,
18.168
]

ax = plt.subplot(111)
ax.errorbar(range(0,4),sum_mean,yerr=sum_std,fmt='o',capsize=7,
            markersize=20,elinewidth=5,capthick=5)
plt.xticks([])
plt.yticks(range(30,7*30+1,30),fontsize=25)
plt.xlim(-0.5,3.5)
plt.ylim(0,8*30)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_linewidth(5)
ax.tick_params('y',length=10,width=5)
plt.savefig('panss_p_n_kmeans_kruskal_wallis_test_sum.png',dpi=300)
